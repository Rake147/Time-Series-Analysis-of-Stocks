# %% [markdown]
# # Time Series Stock Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly

# %%
apple= pd.read_csv('C:/Users/Rakesh/2-Time Series Data Analysis/individual_stocks_5yr/AAPL_data.csv')

# %%
apple
# Out:
#             date      open      high       low     close     volume  Name
# 0     2013-02-08   67.7142   68.4014   66.8928   67.8542  158168416  AAPL
# 1     2013-02-11   68.0714   69.2771   67.6071   68.5614  129029425  AAPL
# 2     2013-02-12   68.5014   68.9114   66.8205   66.8428  151829363  AAPL
# 3     2013-02-13   66.7442   67.6628   66.1742   66.7156  118721995  AAPL
# 4     2013-02-14   66.3599   67.3771   66.2885   66.6556   88809154  AAPL
# ...          ...       ...       ...       ...       ...        ...   ...
# 1254  2018-02-01  167.1650  168.6200  166.7600  167.7800   47230787  AAPL
# 1255  2018-02-02  166.0000  166.8000  160.1000  160.5000   86593825  AAPL
# 1256  2018-02-05  159.1000  163.8800  156.0000  156.4900   72738522  AAPL
# 1257  2018-02-06  154.8300  163.7200  154.0000  163.0300   68243838  AAPL
# 1258  2018-02-07  163.0850  163.4000  159.0685  159.5400   51608580  AAPL
#
# [1259 rows x 7 columns]

# %%
google=pd.read_csv('C:/Users/Rakesh/2-Time Series Data Analysis/individual_stocks_5yr/GOOG_data.csv')

# %%
google
# Out:
#            date      open     high      low    close   volume  Name
# 0    2014-03-27   568.000   568.00   552.92   558.46    13052  GOOG
# 1    2014-03-28   561.200   566.43   558.67   559.99    41003  GOOG
# 2    2014-03-31   566.890   567.00   556.93   556.97    10772  GOOG
# 3    2014-04-01   558.710   568.45   558.71   567.16     7932  GOOG
# 4    2014-04-02   565.106   604.83   562.19   567.00   146697  GOOG
# ..          ...       ...      ...      ...      ...      ...   ...
# 970  2018-02-01  1162.610  1174.00  1157.52  1167.70  2412114  GOOG
# 971  2018-02-02  1122.000  1123.07  1107.28  1111.90  4857943  GOOG
# 972  2018-02-05  1090.600  1110.00  1052.03  1055.80  3798301  GOOG
# 973  2018-02-06  1027.180  1081.71  1023.14  1080.60  3447956  GOOG
# 974  2018-02-07  1081.540  1081.78  1048.26  1048.58  2369232  GOOG
#
# [975 rows x 7 columns]

# %%
microsoft=pd.read_csv('C:/Users/Rakesh/2-Time Series Data Analysis/individual_stocks_5yr/MSFT_data.csv')

# %%
microsoft
# Out:
#             date   open    high      low  close    volume  Name
# 0     2013-02-08  27.35  27.710  27.3100  27.55  33318306  MSFT
# 1     2013-02-11  27.65  27.920  27.5000  27.86  32247549  MSFT
# 2     2013-02-12  27.88  28.000  27.7500  27.88  35990829  MSFT
# 3     2013-02-13  27.93  28.110  27.8800  28.03  41715530  MSFT
# 4     2013-02-14  27.92  28.060  27.8700  28.04  32663174  MSFT
# ...          ...    ...     ...      ...    ...       ...   ...
# 1254  2018-02-01  94.79  96.070  93.5813  94.26  47227882  MSFT
# 1255  2018-02-02  93.64  93.970  91.5000  91.78  47867753  MSFT
# 1256  2018-02-05  90.56  93.240  88.0000  88.00  51031465  MSFT
# 1257  2018-02-06  86.89  91.475  85.2500  91.33  67998564  MSFT
# 1258  2018-02-07  90.49  91.770  89.2000  89.61  41107592  MSFT
#
# [1259 rows x 7 columns]

# %%
amazon=pd.read_csv('C:/Users/Rakesh/2-Time Series Data Analysis/individual_stocks_5yr/AMZN_data.csv')

# %%
amazon
# Out:
#             date     open     high       low    close    volume  Name
# 0     2013-02-08   261.40   265.25   260.555   261.95   3879078  AMZN
# 1     2013-02-11   263.20   263.25   256.600   257.21   3403403  AMZN
# 2     2013-02-12   259.19   260.16   257.000   258.70   2938660  AMZN
# 3     2013-02-13   261.53   269.96   260.300   269.47   5292996  AMZN
# 4     2013-02-14   267.37   270.65   265.400   269.24   3462780  AMZN
# ...          ...      ...      ...       ...      ...       ...   ...
# 1254  2018-02-01  1445.00  1459.88  1385.140  1390.00   9113808  AMZN
# 1255  2018-02-02  1477.39  1498.00  1414.000  1429.95  11125722  AMZN
# 1256  2018-02-05  1402.62  1458.98  1320.720  1390.00  11494985  AMZN
# 1257  2018-02-06  1361.46  1443.99  1351.790  1442.84  11066819  AMZN
# 1258  2018-02-07  1449.00  1460.99  1415.150  1416.78   7162741  AMZN
#
# [1259 rows x 7 columns]

# %%
company_list=[apple,microsoft,amazon,google]

# %%
all_data=pd.concat(company_list)
all_data.shape
# Out:
# (4752, 7)

# %%
all_data.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %% [markdown]
# # Analysing Closing Price Of All Stocks

# %%
all_data.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
all_data['date']=pd.to_datetime(all_data['date'])

# %%
all_data.dtypes
# Out:
# date      datetime64[ns]
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# Name              object
# dtype: object

# %%
tech_list=all_data['Name'].unique()

# %%
plt.figure(figsize=(20,12))
for i, company in enumerate(tech_list,1):
    plt.subplot(2,2,i)
    df=all_data[all_data['Name']==company]
    plt.plot(df['date'],df['close'])
    plt.xticks(rotation='vertical')
    plt.title(company)

# %% [markdown]
# # Analysing total volumes of stock traded each day

# %%
import plotly.express as px

# %%
for company in tech_list:
    df=all_data[all_data['Name']==company]
    fig=px.line(df,x='date',y='volume',title=company)
    fig.show()
# Out:
# <div>                            <div id="992b8905-f75c-4e88-bd76-671d2c626051" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("992b8905-f75c-4e88-bd76-671d2c626051")) {                    Plotly.newPlot(                        "992b8905-f75c-4e88-bd76-671d2c626051",                        [{"hovertemplate":"date=%{x}<br>volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-0
# ...

# %% [markdown]
# # Analysing Daily price change

# %%
apple.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
apple['Name'].unique()
# Out:
# array(['AAPL'], dtype=object)

# %%
apple['Daily_price_change']=apple['close']-apple['open']

# %%
apple.head()
# Out:
#          date     open     high      low    close     volume  Name  \
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#    Daily_price_change  1day % return
# 0              0.1400       0.206325
# 1              0.4900       0.714688
# 2             -1.6586      -2.481344
# 3             -0.0286      -0.042869
# 4              0.2957       0.443624

# %%
apple['1day % return']=((apple['close']-apple['open'])/apple['close'])*100

# %%
apple.head()
# Out:
#          date     open     high      low    close     volume  Name  \
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#    Daily_price_change  1day % return
# 0              0.1400       0.206325
# 1              0.4900       0.714688
# 2             -1.6586      -2.481344
# 3             -0.0286      -0.042869
# 4              0.2957       0.443624

# %%
fig1=px.line(apple,x='date',y='1day % return',title=company)
fig.show()
# Out:
# <div>                            <div id="a23458d9-51c5-4ff8-9199-b701d6752d59" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a23458d9-51c5-4ff8-9199-b701d6752d59")) {                    Plotly.newPlot(                        "a23458d9-51c5-4ff8-9199-b701d6752d59",                        [{"hovertemplate":"date=%{x}<br>volume=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2014-03-27T00:00:00","2014-03-28T00:00:00","2014-03-31T00:00:00","2014-04-01T00:00:00","2014-04-02T00:00:00","2014-04-03T00:00:00","2014-04-04T00:00:00","2014-04-07T00:00:00","2014-04-08T00:00:00","2014-04-09T00:00:00","2014-04-10T00:00:00","2014-04-11
# ...

# %% [markdown]
# # Analysing Monthly & Yearly wise stock price

# %%
df2=apple.copy()

# %%
df2.dtypes
# Out:
# date                   object
# open                  float64
# high                  float64
# low                   float64
# close                 float64
# volume                  int64
# Name                   object
# Daily_price_change    float64
# 1day % return         float64
# dtype: object

# %%
df2['date']=pd.to_datetime(df2['date'])

# %%
df2.head()
# Out:
#         date     open     high      low    close     volume  Name  \
# 0 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#    Daily_price_change  1day % return
# 0              0.1400       0.206325
# 1              0.4900       0.714688
# 2             -1.6586      -2.481344
# 3             -0.0286      -0.042869
# 4              0.2957       0.443624

# %%
df2.set_index('date',inplace=True)

# %%
df2.head()
# Out:
#                open     high      low    close     volume  Name  \
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#             Daily_price_change  1day % return
# date
# 2013-02-08              0.1400       0.206325
# 2013-02-11              0.4900       0.714688
# 2013-02-12             -1.6586      -2.481344
# 2013-02-13             -0.0286      -0.042869
# 2013-02-14              0.2957       0.443624

# %%
df2['close'].resample('M').mean()
# Out:
# date
# 2013-02-28     65.306264
# 2013-03-31     63.120110
# 2013-04-30     59.966432
# 2013-05-31     63.778927
# 2013-06-30     60.791120
#                  ...
# 2017-10-31    157.817273
# 2017-11-30    172.406190
# 2017-12-31    171.891500
# 2018-01-31    174.005238
# 2018-02-28    161.468000
# Freq: M, Name: close, Length: 61, dtype: float64

# %%
df2['close'].resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df2['close'].resample('Y').mean()
# Out:
# date
# 2013-12-31     67.237839
# 2014-12-31     92.264531
# 2015-12-31    120.039861
# 2016-12-31    104.604008
# 2017-12-31    150.585080
# 2018-12-31    171.594231
# Freq: A-DEC, Name: close, dtype: float64

# %%
df2['close'].resample('Y').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
aapl=pd.read_csv('C:/Users/Rakesh/2-Time Series Data Analysis/individual_stocks_5yr/AAPL_data.csv')
amzn=pd.read_csv('C:/Users/Rakesh/2-Time Series Data Analysis/individual_stocks_5yr/AMZN_data.csv')
micro=pd.read_csv('C:/Users/Rakesh/2-Time Series Data Analysis/individual_stocks_5yr/GOOG_data.csv')
goog=pd.read_csv('C:/Users/Rakesh/2-Time Series Data Analysis/individual_stocks_5yr/MSFT_data.csv')

# %%
aapl.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
amzn.head()
# Out:
#          date    open    high      low   close   volume  Name
# 0  2013-02-08  261.40  265.25  260.555  261.95  3879078  AMZN
# 1  2013-02-11  263.20  263.25  256.600  257.21  3403403  AMZN
# 2  2013-02-12  259.19  260.16  257.000  258.70  2938660  AMZN
# 3  2013-02-13  261.53  269.96  260.300  269.47  5292996  AMZN
# 4  2013-02-14  267.37  270.65  265.400  269.24  3462780  AMZN

# %%
micro.head()
# Out:
#          date     open    high     low   close  volume  Name
# 0  2014-03-27  568.000  568.00  552.92  558.46   13052  GOOG
# 1  2014-03-28  561.200  566.43  558.67  559.99   41003  GOOG
# 2  2014-03-31  566.890  567.00  556.93  556.97   10772  GOOG
# 3  2014-04-01  558.710  568.45  558.71  567.16    7932  GOOG
# 4  2014-04-02  565.106  604.83  562.19  567.00  146697  GOOG

# %%
goog.head()
# Out:
#          date   open   high    low  close    volume  Name
# 0  2013-02-08  27.35  27.71  27.31  27.55  33318306  MSFT
# 1  2013-02-11  27.65  27.92  27.50  27.86  32247549  MSFT
# 2  2013-02-12  27.88  28.00  27.75  27.88  35990829  MSFT
# 3  2013-02-13  27.93  28.11  27.88  28.03  41715530  MSFT
# 4  2013-02-14  27.92  28.06  27.87  28.04  32663174  MSFT

# %%
close=pd.DataFrame()

# %%
close['apple']=aapl['close']
close['google']=goog['close']
close['microsoft']=micro['close']
close['amazon']=amzn['close']

# %%
close.head()
# Out:
#      apple  google  microsoft  amazon
# 0  67.8542   27.55     558.46  261.95
# 1  68.5614   27.86     559.99  257.21
# 2  66.8428   27.88     556.97  258.70
# 3  66.7156   28.03     567.16  269.47
# 4  66.6556   28.04     567.00  269.24

# %%
import seaborn as sns

# %%
sns.pairplot(data=close)

# %%
sns.heatmap(close.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
aapl.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
data=pd.DataFrame()

# %%
data['aapl_change']=((aapl['close']-aapl['open'])/aapl['close'])*100
data['amzn_change']=((amzn['close']-amzn['open'])/amzn['close'])*100
data['micro_change']=((micro['close']-micro['open'])/micro['close'])*100
data['goog_change']=((goog['close']-goog['open'])/goog['close'])*100

# %%
data.head()
# Out:
#    aapl_change  amzn_change  micro_change  goog_change
# 0     0.206325     0.209964     -1.708269     0.725953
# 1     0.714688    -2.328836     -0.216075     0.753769
# 2    -2.481344    -0.189409     -1.781065     0.000000
# 3    -0.042869     2.946525      1.489879     0.356761
# 4     0.443624     0.694548      0.334039     0.427960

# %%
sns.pairplot(data=data)

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(data['aapl_change'])
# Out:
# C:\Users\Rakesh\Downloads\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='aapl_change', ylabel='Density'>

# %%
sns.distplot(data['amzn_change'])
# Out:
# C:\Users\Rakesh\Downloads\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='amzn_change', ylabel='Density'>

# %%
sns.distplot(data['micro_change'])
# Out:
# C:\Users\Rakesh\Downloads\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='micro_change', ylabel='Density'>

# %%
sns.distplot(data['goog_change'])
# Out:
# C:\Users\Rakesh\Downloads\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='goog_change', ylabel='Density'>

# %%
data['aapl_change'].std()
### 68% of the data is present between -1.187 to +1.187
# Out:
# 1.1871377131421237

# %%
data['aapl_change'].std()*2
### 95% of the data is present between -2.374 to +2.374
# Out:
# 2.3742754262842474

# %%
data['aapl_change'].std()*3
### 99.7% of the data is present between -3.56 to +3.56
# Out:
# 3.561413139426371

# %%
data.describe()
# Out:
#        aapl_change  amzn_change  micro_change  goog_change
# count  1259.000000  1259.000000    975.000000  1259.000000
# mean     -0.000215    -0.000398     -0.012495     0.076404
# std       1.187138     1.358679      1.092560     1.059260
# min      -7.104299    -9.363077     -5.952266    -5.177618
# 25%      -0.658021    -0.738341     -0.551963    -0.509241
# 50%       0.042230    -0.002623      0.024951     0.061069
# 75%       0.715427     0.852568      0.672649     0.703264
# max       8.000388     5.640265      4.943550     4.861491
